# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

team_data = pd.read_csv('../data/team_data.csv')
game_data = pd.read_csv('../data/game_data.csv')

# %%
team_data.head()
# Out:
#       TEAM_ID          TEAM_NAME  GP   W   L  W_PCT     MIN   FGM   FGA  \
# 0  1610612737      Atlanta Hawks  36  18  18  0.500  1738.0  1537  3314
# 1  1610612738     Boston Celtics  36  26  10  0.722  1743.0  1504  3270
# 2  1610612751      Brooklyn Nets  36  13  23  0.361  1738.0  1372  3049
# 3  1610612766  Charlotte Hornets  34   7  27  0.206  1647.0  1299  3050
# 4  1610612741      Chicago Bulls  36  17  19  0.472  1733.0  1554  3325
#
#    FG_PCT  ...  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 0   0.464  ...         4         3        26         2        10         23
# 1   0.460  ...         7        15         2        20         6          2
# 2   0.450  ...        29        16        22        28        29         26
# 3   0.426  ...        15        28        20        22        20         21
# 4   0.467  ...         6         4        19        20        21         17
#
#    PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# ...

# %%
game_data.head()
# Out:
#     GAME_ID  TEAM_ID_HOME  PTS_HOME  REB_HOME  AST_HOME  STL_HOME  BLK_HOME  \
# 0  22400061    1610612738       132        40        33         6         3
# 1  22400062    1610612747       110        46        22         7         8
# 2  22400071    1610612746       113        51        27         9         1
# 3  22400066    1610612755       109        49        18         4         2
# 4  22400063    1610612765       109        38        22         6         2
#
#    TOV_HOME  TEAM_ID_AWAY  PTS_AWAY  REB_AWAY  AST_AWAY  STL_AWAY  BLK_AWAY  \
# 0         4    1610612752       109        34        20         2         3
# 1         7    1610612750       103        47        17         4         1
# 2        22    1610612756       116        42        25        12         9
# 3        10    1610612749       124        46        27         4         9
# 4        14    1610612754       115        39        32        10         8
#
#    TOV_AWAY  HOME_WIN
# 0        12         1
# ...

# %%
if 'TEAM_NAME' in team_data.columns and 'W' in team_data.columns and 'L' in team_data.columns:
    team_data['Win_Percentage'] = team_data['W'] / (team_data['W'] + team_data['L'])
    win_percentage = team_data.groupby('TEAM_NAME')['Win_Percentage'].mean().sort_values()
    win_percentage.plot(kind='barh', figsize=(10, 8), color='gold')
    plt.title("Win Percentage by Team")
    plt.xlabel("Win Percentage")
    plt.ylabel("Team Name")
    plt.show()

# %%
if 'TEAM_NAME' in team_data.columns and 'FG_PCT' in team_data.columns:
    team_avg_fg_pct = team_data.groupby('TEAM_NAME')['FG_PCT'].mean().sort_values()
    team_avg_fg_pct.plot(kind='barh', figsize=(10, 8), color='teal')
    plt.title("Average Field Goal Percentage by Team")
    plt.xlabel("Field Goal Percentage")
    plt.ylabel("Team Name")
    plt.show()

# %%
if 'AST' in team_data.columns and 'TOV' in team_data.columns:
    team_data['AST_TOV_Ratio'] = team_data['AST'] / team_data['TOV']
    ast_tov_ratio = team_data.groupby('TEAM_NAME')['AST_TOV_Ratio'].mean().sort_values()
    ast_tov_ratio.plot(kind='barh', figsize=(10, 8), color='brown')
    plt.title("Assist-to-Turnover Ratio by Team")
    plt.xlabel("Assist-to-Turnover Ratio")
    plt.ylabel("Team Name")
    plt.show()
